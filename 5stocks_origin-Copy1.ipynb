# %%
import pandas as pd
import pandas_datareader.data as web
import datetime 
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
#数据开始和结束时间
start=datetime.datetime(2010,1,1)
end=datetime.datetime(2020,1,1)

# %%
#实验中提取的股票
#AAPL
#GOOGL
#INTC
#MSFT
#ORCL

# %%
web.get_data_yahoo('AAPL',start,end).head(5)
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 2009-12-31  7.619643  7.520000  7.611786  7.526072  352410800.0   6.503574
# 2010-01-04  7.660714  7.585000  7.622500  7.643214  493729600.0   6.604801
# 2010-01-05  7.699643  7.616071  7.664286  7.656428  601904800.0   6.616219
# 2010-01-06  7.686786  7.526786  7.656428  7.534643  552160000.0   6.510980
# 2010-01-07  7.571429  7.466072  7.562500  7.520714  477131200.0   6.498945

# %%
#获得股票数据
tech=['GOOGL','INTC','MSFT','ORCL']
df=pd.DataFrame({'AAPL':web.get_data_yahoo('AAPL',start,end)['Adj Close']})
for i in tech:
    tmp=web.get_data_yahoo(i,start,end)['Adj Close']
    tmp=tmp.rename(i)
    df=pd.merge(df,tmp,how='left',left_index=True,right_index=True)

# %%
df.head()
#df.to_csv('D:/DataMining/基于深度学习的金融时序预测/stocks.csv')
# Out:
#                 AAPL       GOOGL       INTC       MSFT       ORCL
# Date
# 2009-12-31  6.503574  310.300293  14.717187  23.801456  21.325991
# 2010-01-04  6.604801  313.688690  15.063472  24.168472  21.604193
# 2010-01-05  6.616219  312.307312  15.056260  24.176279  21.578108
# 2010-01-06  6.510980  304.434448  15.005755  24.027906  21.265123
# 2010-01-07  6.498945  297.347351  14.861475  23.778025  21.195576

# %%
#数据预处理
#df_pro=(df-df.mean())/df.std()
df_pro=(df.pct_change()).fillna(0)
#df_pro=(df-df.min())/(df.max()-df.min())

# %%
df_pro.head()
# Out:
#                 AAPL     GOOGL      INTC      MSFT      ORCL
# Date
# 2009-12-31  0.000000  0.000000  0.000000  0.000000  0.000000
# 2010-01-04  0.015565  0.010920  0.023529  0.015420  0.013045
# 2010-01-05  0.001729 -0.004404 -0.000479  0.000323 -0.001207
# 2010-01-06 -0.015906 -0.025209 -0.003354 -0.006137 -0.014505
# 2010-01-07 -0.001848 -0.023280 -0.009615 -0.010400 -0.003271

# %%
#数据预览
plt.figure(figsize=(10,5))
for i in df_pro.columns:
    plt.plot(df_pro[i])
plt.show()

# %%
#参数
time_size=20
input_size=5

# %%
#不重叠地切分 -- 250 *20 的数据量
#last=df_pro.shape[0]//time_size*time_size
#input_data=np.split(df_pro.values[:last],last/time_size,axis=0)
df_pro.shape[0] // time_size*time_size
# Out:
# 2500

# %%
#重叠切分
input_data=[]
output_data=[]
seq=df_pro.values
for i in range(len(seq)-time_size-1):
    input_data.append(seq[i:i+time_size])
    output_data.append(seq[i+time_size+1])
input_data=np.array(input_data)
output_data=np.array(output_data)

# %%
print(input_data.shape)
print(output_data.shape)
# Out:
# (2496, 20, 5)
# (2496, 5)

# %%
#实验模型
class ARNNCell(tf.keras.layers.Layer):
    def __init__(self, input_dim, output_dim):
        super(ARNNCell, self).__init__()
        self.input_dim=input_dim
        self.output_dim=output_dim
        self.w1=keras.layers.Dense(input_dim, activation='sigmoid')
        self.w2=keras.layers.Dense(input_dim, activation='tanh')
        self.w3=keras.layers.Dense(input_dim, activation='tanh')
        self.w4=keras.layers.Dense(output_dim, activation='linear')        
        self.state_size=(self.input_dim,self.input_dim)

    def call(self, inputs, states):
        pre_h=states[0]
        pre_h1=states[1]
        h=self.w2(inputs)+self.w3(pre_h)
        y=self.w1(inputs)*h
        h1=y+pre_h1
        return self.w4(h1), [h,h1]

def model_build_ATT():
    model=keras.Sequential(keras.layers.RNN(ARNNCell(input_dim=40,output_dim=5)))
    return model

# %%
#单层LSTM模型
def model_build_LSTM():
    model=keras.Sequential()
    model.add(keras.layers.LSTM(units=20,return_sequences=False))
    model.add(keras.layers.Activation('linear'))
    model.add(keras.layers.Dense(units=5))
    return model

# %%
##损失函数
def loss_(y_pred,y_true):
    return tf.reduce_mean(tf.square(y_pred-y_true))+tf.exp(-1*y_pred*y_true)
    #return tf.reduce_mean(tf.square(y_pred-y_true))+100*tf.exp(-(y_pred*y_true)/tf.abs(y_pred*y_true))
    #return tf.reduce_mean(tf.square(y_pred-y_true))+tf.exp(-10000*(y_pred*y_true))

# %%
#data to [train,test]
#数据切分成训练数据和测试数据
train_size=int(input_data.shape[0]*0.8)
train_x=input_data[:train_size]
test_x=input_data[train_size+1:]
train_y=output_data[:train_size]
test_y=output_data[train_size+1:]

# %%
#模型训练函数
def train_model(train_x,train_y,test_x,test_y):
    model=model_build_ATT()
    #model=model_build_LSTM()
    model_name='att'

    #model.compile(loss='mse',optimizer='adam')
    model.compile(loss='mse',optimizer='adam')
    history=model.fit(train_x,train_y,batch_size=4,epochs=200,verbose=1,shuffle=False)
    model.summary()
    
    loss = history.history['loss']
    predict=model.predict(test_x)
    return predict,loss,model_name

# %%
print(train_x.shape,test_x.shape,train_y.shape,test_y.shape)
# Out:
# (1996, 20, 5) (499, 20, 5) (1996, 5) (499, 5)

# %%
#训练模型
predict,loss,model=train_model(train_x, train_y, test_x, test_y)
# Out:
# Train on 1996 samples
# Epoch 1/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 0.0016
# Epoch 2/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 5.2948e-04
# Epoch 3/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 4.4342e-04
# Epoch 4/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 4.0189e-04
# Epoch 5/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.6158e-04
# Epoch 6/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.3437e-04
# Epoch 7/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.1918e-04
# Epoch 8/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.0787e-04
# Epoch 9/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9993e-04
# Epoch 10/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9237e-04
# Epoch 11/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.8649e-04
# Epoch 12/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7211e-04
# Epoch 13/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.5950e-04
# Epoch 14/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.4974e-04
# Epoch 15/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.4047e-04
# Epoch 16/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.3468e-04
# Epoch 17/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.3178e-04
# Epoch 18/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2992e-04
# Epoch 19/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2841e-04
# Epoch 20/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2746e-04
# Epoch 21/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2690e-04
# Epoch 22/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2621e-04
# Epoch 23/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2621e-04
# Epoch 24/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2614e-04
# Epoch 25/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2587e-04
# Epoch 26/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.3186e-04
# Epoch 27/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2481e-04
# Epoch 28/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2529e-04
# Epoch 29/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2523e-04
# Epoch 30/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2591e-04
# Epoch 31/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2499e-04
# Epoch 32/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2582e-04
# Epoch 33/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2545e-04
# Epoch 34/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2489e-04
# Epoch 35/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2541e-04
# Epoch 36/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2511e-04
# Epoch 37/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2514e-04
# Epoch 38/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2471e-04
# Epoch 39/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2477e-04
# Epoch 40/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2462e-04
# Epoch 41/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2427e-04
# Epoch 42/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2484e-04
# Epoch 43/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2423e-04
# Epoch 44/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2495e-04
# Epoch 45/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2412e-04
# Epoch 46/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2383e-04
# Epoch 47/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2437e-04
# Epoch 48/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2356e-04
# Epoch 49/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2425e-04
# Epoch 50/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2424e-04
# Epoch 51/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2379e-04
# Epoch 52/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2528e-04
# Epoch 53/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2332e-04
# Epoch 54/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2427e-04
# Epoch 55/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2422e-04
# Epoch 56/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2407e-04
# Epoch 57/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2403e-04
# Epoch 58/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2328e-04
# Epoch 59/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2357e-04
# Epoch 60/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2331e-04
# Epoch 61/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2361e-04
# Epoch 62/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2342e-04
# Epoch 63/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2343e-04
# Epoch 64/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2323e-04
# Epoch 65/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2394e-04
# Epoch 66/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2327e-04
# Epoch 67/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2443e-04
# Epoch 68/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2325e-04
# Epoch 69/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2310e-04
# Epoch 70/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2359e-04
# Epoch 71/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2356e-04
# Epoch 72/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2317e-04
# Epoch 73/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2293e-04
# Epoch 74/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2299e-04
# Epoch 75/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2284e-04
# Epoch 76/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2277e-04
# Epoch 77/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2303e-04
# Epoch 78/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2279e-04
# Epoch 79/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2283e-04
# Epoch 80/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2280e-04
# Epoch 81/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2275e-04
# Epoch 82/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2272e-04
# Epoch 83/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2319e-04
# Epoch 84/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2270e-04
# Epoch 85/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2277e-04
# Epoch 86/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2263e-04
# Epoch 87/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2309e-04
# Epoch 88/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2284e-04
# Epoch 89/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2249e-04
# Epoch 90/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2254e-04
# Epoch 91/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2265e-04
# Epoch 92/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2267e-04
# Epoch 93/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2277e-04
# Epoch 94/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2240e-04
# Epoch 95/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2256e-04
# Epoch 96/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2244e-04
# Epoch 97/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2233e-04
# Epoch 98/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2246e-04
# Epoch 99/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2236e-04
# Epoch 100/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2228e-04
# Epoch 101/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2229e-04
# Epoch 102/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2201e-04
# Epoch 103/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2199e-04
# Epoch 104/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2207e-04
# Epoch 105/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2503e-04
# Epoch 106/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2366e-04
# Epoch 107/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2370e-04
# Epoch 108/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2397e-04
# Epoch 109/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2279e-04
# Epoch 110/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2270e-04
# Epoch 111/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2275e-04
# Epoch 112/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2284e-04
# Epoch 113/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2293e-04
# Epoch 114/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2556e-04
# Epoch 115/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2337e-04
# Epoch 116/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2303e-04
# Epoch 117/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2286e-04
# Epoch 118/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2271e-04
# Epoch 119/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2273e-04
# Epoch 120/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2280e-04
# Epoch 121/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2281e-04
# Epoch 122/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2280e-04
# Epoch 123/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2281e-04
# Epoch 124/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2282e-04
# Epoch 125/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2284e-04
# Epoch 126/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2283e-04
# Epoch 127/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2281e-04
# Epoch 128/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2282e-04
# Epoch 129/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2283e-04
# Epoch 130/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2281e-04
# Epoch 131/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2277e-04
# Epoch 132/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2274e-04
# Epoch 133/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2272e-04
# Epoch 134/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2268e-04
# Epoch 135/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2264e-04
# Epoch 136/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2259e-04
# Epoch 137/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2257e-04
# Epoch 138/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2255e-04
# Epoch 139/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2570e-04
# Epoch 140/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2258e-04
# Epoch 141/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2256e-04
# Epoch 142/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2231e-04
# Epoch 143/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2231e-04
# Epoch 144/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2230e-04
# Epoch 145/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2231e-04
# Epoch 146/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2442e-04
# Epoch 147/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2386e-04
# Epoch 148/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2327e-04
# Epoch 149/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2305e-04
# Epoch 150/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2380e-04
# Epoch 151/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2400e-04
# Epoch 152/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2370e-04
# Epoch 153/200
# 1996/1996 [==============================] - 2s 976us/sample - loss: 2.2342e-04
# Epoch 154/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2395e-04
# Epoch 155/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2378e-04
# Epoch 156/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2310e-04
# Epoch 157/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2309e-04
# Epoch 158/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2287e-04
# Epoch 159/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2270e-04
# Epoch 160/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.2266e-04
# Epoch 161/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2270e-04
# Epoch 162/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2280e-04
# Epoch 163/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2269e-04
# Epoch 164/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2264e-04
# Epoch 165/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2266e-04
# Epoch 166/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2264e-04
# Epoch 167/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2274e-04
# Epoch 168/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2264e-04
# Epoch 169/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2261e-04
# Epoch 170/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2260e-04
# Epoch 171/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2261e-04
# Epoch 172/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2260e-04
# Epoch 173/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2278e-04
# Epoch 174/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2269e-04
# Epoch 175/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2264e-04
# Epoch 176/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2283e-04
# Epoch 177/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2245e-04
# Epoch 178/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2249e-04
# Epoch 179/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2242e-04
# Epoch 180/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2306e-04
# Epoch 181/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2258e-04
# Epoch 182/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2243e-04
# Epoch 183/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2241e-04
# Epoch 184/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2237e-04
# Epoch 185/200
# 1996/1996 [==============================] - 2s 989us/sample - loss: 2.2231e-04
# Epoch 186/200
# 1996/1996 [==============================] - 2s 988us/sample - loss: 2.2268e-04
# Epoch 187/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2235e-04
# Epoch 188/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2236e-04
# Epoch 189/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2239e-04
# Epoch 190/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2241e-04
# Epoch 191/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2368e-04
# Epoch 192/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2431e-04
# Epoch 193/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2335e-04
# Epoch 194/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2288e-04
# Epoch 195/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2373e-04
# Epoch 196/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2316e-04
# Epoch 197/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2311e-04
# Epoch 198/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2280e-04
# Epoch 199/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2307e-04
# Epoch 200/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.2290e-04
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn (RNN)                    multiple                  2325
# =================================================================
# Total params: 2,325
# Trainable params: 2,325
# Non-trainable params: 0
# _________________________________________________________________

# %%
predict.shape
# Out:
# (499, 5)

# %%
#真实和预测结果
test_y_list=np.split(test_y,5,axis=1)
predict_list=np.split(predict,5,axis=1)
for i in range(5):
    plt.figure(figsize=(10,5))
    plt.plot(test_y_list[i],label='real')
    plt.plot(predict_list[i],label='predict')
    plt.legend()
    plt.show()

# %%
test_y_list=np.split(test_y,5,axis=1)
predict_list=np.split(predict,5,axis=1)
for i in range(5):
    plt.figure(figsize=(10,5))
    plt.plot(test_y_list[i],label='real')
    plt.plot(predict_list[i],label='predict')
    plt.legend()
    plt.show()

# %%
print('rmse:{}'.format(np.sqrt(np.mean(np.square(predict-test_y)))))
# Out:
# rmse:0.016725703921306963

# %%
#选取增量最大的股票进行投递  数据为价格
def stragety():
    #init
    cap_str=100000
    cap_cg=[cap_str]
    for i in range(len(predict)-1):
        cur,ind=0,-1
        for j in range(input_size):
            if(predict[i+1][j]/predict[i][j]-1>cur):
                cur=predict[i+1][j]/predict[i][j]-1
                ind=j
        if cur>0:
            cap_str=cap_str*test_y[i+1][ind]/test_y[i][ind]
        cap_cg.append(cap_str)
    return cap_cg

def origin():
    cap_ori=100000
    cap_cg=[cap_ori]
    for i in range(len(predict)-1):
        cap_ori=cap_ori*test_y[i+1][0]/test_y[i][0]
        cap_cg.append(cap_ori)
    return cap_cg

# %%
#选取增量最大的股票进行投递  数据为增长率
def stragety_rate():
    #init
    cap_str=100000
    cap_cg=[cap_str]
    for i in range(len(predict)-1):
        cur,ind=0,-1
        for j in range(input_size):
            if(predict[i+1][j]>cur):
                cur=predict[i+1][j]
                ind=j
        if cur>0:
            cap_str=cap_str*(1+test_y[i+1][ind])
        cap_cg.append(cap_str)
    return cap_cg

def origin_rate():
    cap_ori=100000
    cap_cg=[cap_ori]
    for i in range(len(predict)-1):
        cap_ori=cap_ori*(1+test_y[i+1][0])
        cap_cg.append(cap_ori)
    return cap_cg

# %%
#策略结果  数据为价格
cap_s=stragety()
cap_o=origin()
plt.plot(cap_s)
plt.plot(cap_o)
plt.show()
# Out:
# C:\Users\jingw\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in double_scalars
#   del sys.path[0]

# %%
#策略结果 数据为增长率
cap_s=stragety_rate()
cap_o=origin_rate()
plt.plot(cap_s)
plt.plot(cap_o)
plt.show()

# %%
def log():
# Out:
#   File "<ipython-input-29-6153ca42db5c>", line 1
#     def log():
#               ^
# SyntaxError: unexpected EOF while parsing
