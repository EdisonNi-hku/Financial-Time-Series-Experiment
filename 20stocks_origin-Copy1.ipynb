# %%
import pandas as pd
import pandas_datareader.data as web
import datetime
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
import time

# %%
#数据开始和结束时间
start=datetime.datetime(2010,1,1)
end=datetime.datetime(2020,1,1)

# %%
#实验中提取的股票
#AAPL
#GOOGL
#INTC
#MSFT
#ORCL

# %%
web.get_data_yahoo('AAL',start,end).head(5)
# Out:
#             High   Low  Open  Close      Volume  Adj Close
# Date
# 2009-12-31  4.97  4.83  4.92   4.84   5268600.0   4.562870
# 2010-01-04  4.94  4.66  4.84   4.77   9837300.0   4.496876
# 2010-01-05  5.37  4.71  4.79   5.31  25212000.0   5.005957
# 2010-01-06  5.38  5.00  5.19   5.09  16597900.0   4.798555
# 2010-01-07  5.43  5.05  5.06   5.24  14033400.0   4.939965

# %%
#获得股票数据
stock_names = pd.read_csv('D:/DataMining/基于深度学习的金融时序预测/stock_list_name.csv', header=None)
tech = list(stock_names[0][1:20])
df=pd.DataFrame({'AAL':web.get_data_yahoo('AAL',start,end)['Adj Close']})
for i in tech:
    tmp=web.get_data_yahoo(i,start,end)['Adj Close']
    tmp=tmp.rename(i)
    df=pd.merge(df,tmp,how='left',left_index=True,right_index=True)

# %%
df.head()
# Out:
#                  AAL      AAPL       ADBE        ADI        ADP       ADSK  \
# Date
# 2009-12-31  4.562870  6.503574  36.779999  23.933790  28.693487  25.410000
# 2010-01-04  4.496876  6.604801  37.090000  24.001997  28.700174  25.670000
# 2010-01-05  5.005957  6.616219  37.700001  23.964100  28.546061  25.280001
# 2010-01-06  4.798555  6.510980  37.619999  23.918631  28.479050  25.340000
# 2010-01-07  4.939965  6.498945  36.889999  23.729166  28.465643  25.480000
#
#                  AKAM       ALXN       AMAT   AMD       AMGN        AMZN  \
# Date
# 2009-12-31  25.340000  24.410000  11.226706  9.68  45.404182  134.520004
# 2010-01-04  25.920000  24.125000  11.516642  9.70  46.327202  133.899994
# 2010-01-05  26.690001  23.780001  11.428047  9.71  45.925884  134.690002
# 2010-01-06  26.469999  23.840000  11.403889  9.57  45.580757  132.250000
# 2010-01-07  26.480000  23.930000  11.283082  9.47  45.163395  130.000000
#
#                  ATVI       AVGO       BBBY       BIIB  CA  CBOE       CERN  \
# Date
# 2009-12-31   9.956354  14.647326  33.489525  53.500000 NaN   NaN  20.289675
# 2010-01-04  10.126624  15.103806  33.853825  53.639999 NaN   NaN  20.740063
# 2010-01-05  10.144546  15.215920  33.541565  53.380001 NaN   NaN  21.965714
# 2010-01-06  10.090778  15.336046  34.027306  53.430000 NaN   NaN  22.197060
# 2010-01-07   9.848815  15.239952  36.377907  52.990002 NaN   NaN  22.327499
#
#                  CHRW
# Date
# 2009-12-31  45.841454
# 2010-01-04  46.317581
# 2010-01-05  45.357510
# 2010-01-06  44.756481
# 2010-01-07  44.327217

# %%
#数据预处理
#df_pro=(df-df.mean())/df.std()
df_pro=(df.pct_change()).fillna(0)
#df_pro=(df-df.min())/(df.max()-df.min())

# %%
df_pro.head()
# Out:
#                  AAL      AAPL      ADBE       ADI       ADP      ADSK  \
# Date
# 2009-12-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2010-01-04 -0.014463  0.015565  0.008429  0.002850  0.000233  0.010232
# 2010-01-05  0.113208  0.001729  0.016446 -0.001579 -0.005370 -0.015193
# 2010-01-06 -0.041431 -0.015906 -0.002122 -0.001897 -0.002347  0.002373
# 2010-01-07  0.029469 -0.001848 -0.019405 -0.007921 -0.000471  0.005525
#
#                 AKAM      ALXN      AMAT       AMD      AMGN      AMZN  \
# Date
# 2009-12-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2010-01-04  0.022889 -0.011676  0.025826  0.002066  0.020329 -0.004609
# 2010-01-05  0.029707 -0.014300 -0.007693  0.001031 -0.008663  0.005900
# 2010-01-06 -0.008243  0.002523 -0.002114 -0.014418 -0.007515 -0.018116
# 2010-01-07  0.000378  0.003775 -0.010593 -0.010449 -0.009157 -0.017013
#
#                 ATVI      AVGO      BBBY      BIIB   CA  CBOE      CERN  \
# Date
# 2009-12-31  0.000000  0.000000  0.000000  0.000000  0.0   0.0  0.000000
# 2010-01-04  0.017102  0.031165  0.010878  0.002617  0.0   0.0  0.022198
# 2010-01-05  0.001770  0.007423 -0.009224 -0.004847  0.0   0.0  0.059096
# 2010-01-06 -0.005300  0.007895  0.014482  0.000937  0.0   0.0  0.010532
# 2010-01-07 -0.023979 -0.006266  0.069080 -0.008235  0.0   0.0  0.005876
#
#                 CHRW
# Date
# 2009-12-31  0.000000
# 2010-01-04  0.010386
# 2010-01-05 -0.020728
# 2010-01-06 -0.013251
# 2010-01-07 -0.009591

# %%
#数据预览
plt.figure(figsize=(10,5))
for i in df_pro.columns:
    plt.plot(df_pro[i])
plt.show()

# %%
#参数
time_size=20
input_size=20

# %%
#不重叠地切分 -- 250 *20 的数据量
#last=df_pro.shape[0]//time_size*time_size
#input_data=np.split(df_pro.values[:last],last/time_size,axis=0)

# %%
#重叠切分
input_data=[]
output_data=[]
seq=df_pro.values
for i in range(len(seq)-time_size-1):
    input_data.append(seq[i:i+time_size])
    output_data.append(seq[i+time_size+1])
input_data=np.array(input_data)
output_data=np.array(output_data)

# %%
print(input_data.shape)
print(output_data.shape)
# Out:
# (2496, 20, 20)
# (2496, 20)

# %%
#实验模型
class ARNNCell(tf.keras.layers.Layer):
    def __init__(self, input_dim, output_dim):
        super(ARNNCell, self).__init__()
        self.input_dim=input_dim
        self.output_dim=output_dim
        self.w1=keras.layers.Dense(input_dim, activation='tanh')
        self.w2=keras.layers.Dense(input_dim, activation='tanh')
        self.w3=keras.layers.Dense(input_dim, activation='tanh')
        self.w4=keras.layers.Dense(output_dim, activation='linear')        
        self.state_size=(self.input_dim,self.input_dim)

    def call(self, inputs, states):
        pre_h=states[0]
        pre_h1=states[1]
        h=self.w2(inputs)+self.w3(pre_h)
        y=self.w1(inputs)*h
        h1=y+pre_h1
        return self.w4(h1), [h,h1]

def model_build_ATT():
    model=keras.Sequential(keras.layers.RNN(ARNNCell(input_dim=60,output_dim=20)))
    return model

# %%
#单层LSTM模型
def model_build_LSTM():
    model=keras.Sequential()
    model.add(keras.layers.LSTM(units=20,return_sequences=False))
    model.add(keras.layers.Activation('linear'))
    model.add(keras.layers.Dense(units=5))
    return model

# %%
##损失函数
def loss_(y_pred,y_true):
    return tf.reduce_mean(tf.square(y_pred-y_true))+tf.exp(-1*y_pred*y_true)
    #return tf.reduce_mean(tf.square(y_pred-y_true))+100*tf.exp(-(y_pred*y_true)/tf.abs(y_pred*y_true))
    #return tf.reduce_mean(tf.square(y_pred-y_true))+tf.exp(-10000*(y_pred*y_true))

# %%
#data to [train,test]
#数据切分成训练数据和测试数据
train_size=int(input_data.shape[0]*0.8)
train_x=input_data[:train_size]
test_x=input_data[train_size+1:]
train_y=output_data[:train_size]
test_y=output_data[train_size+1:]

# %%
#模型训练函数
def train_model(train_x,train_y,test_x,test_y):
    model=model_build_ATT()
    #model=model_build_LSTM()
    model_name='att'

    #model.compile(loss='mse',optimizer='adam')
    model.compile(loss='mse',optimizer='adam')
    history=model.fit(train_x,train_y,batch_size=4,epochs=200,verbose=1,shuffle=False)
    model.summary()
    
    loss = history.history['loss']
    predict=model.predict(test_x)
    return predict,loss,model_name

# %%
print(train_x.shape,test_x.shape,train_y.shape,test_y.shape)
# Out:
# (1996, 20, 20) (499, 20, 20) (1996, 20) (499, 20)

# %%
#训练模型
time_start = time.time()
predict,loss,model=train_model(train_x, train_y, test_x, test_y)
time_end = time.time()
print("The training process takes: " + str(time_end - time_start) + 's')
# Out:
# Train on 1996 samples
# Epoch 1/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 4.0382e-04
# Epoch 2/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.9559e-04
# Epoch 3/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.9270e-04
# Epoch 4/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.9036e-04
# Epoch 5/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.8785e-04
# Epoch 6/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.8567e-04
# Epoch 7/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.8404e-04
# Epoch 8/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.8095e-04
# Epoch 9/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.7887e-04
# Epoch 10/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.7690e-04
# Epoch 11/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.7402e-04
# Epoch 12/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.7176e-04
# Epoch 13/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.7018e-04
# Epoch 14/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6889e-04
# Epoch 15/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6614e-04
# Epoch 16/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6598e-04
# Epoch 17/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6281e-04
# Epoch 18/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6318e-04
# Epoch 19/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6324e-04
# Epoch 20/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6032e-04
# Epoch 21/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5992e-04
# Epoch 22/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6447e-04
# Epoch 23/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6014e-04
# Epoch 24/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5939e-04
# Epoch 25/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5521e-04
# Epoch 26/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6111e-04
# Epoch 27/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6461e-04
# Epoch 28/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.6257e-04
# Epoch 29/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5963e-04
# Epoch 30/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5830e-04
# Epoch 31/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5398e-04
# Epoch 32/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5329e-04
# Epoch 33/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5222e-04
# Epoch 34/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5642e-04
# Epoch 35/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5085e-04
# Epoch 36/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5316e-04
# Epoch 37/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5354e-04
# Epoch 38/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5028e-04
# Epoch 39/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5211e-04
# Epoch 40/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5140e-04
# Epoch 41/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5882e-04
# Epoch 42/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5658e-04
# Epoch 43/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5558e-04
# Epoch 44/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5558e-04
# Epoch 45/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5436e-04
# Epoch 46/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5507e-04
# Epoch 47/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5756e-04
# Epoch 48/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5265e-04
# Epoch 49/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4797e-04
# Epoch 50/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5106e-04
# Epoch 51/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4970e-04
# Epoch 52/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4655e-04
# Epoch 53/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4856e-04
# Epoch 54/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5137e-04
# Epoch 55/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5119e-04
# Epoch 56/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4557e-04
# Epoch 57/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5193e-04
# Epoch 58/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5000e-04
# Epoch 59/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.5008e-04
# Epoch 60/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4647e-04
# Epoch 61/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4677e-04
# Epoch 62/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.
200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4321e-04
# Epoch 164/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3499e-04
# Epoch 165/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3273e-04
# Epoch 166/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3143e-04
# Epoch 167/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2753e-04
# Epoch 168/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2794e-04
# Epoch 169/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3219e-04
# Epoch 170/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2813e-04
# Epoch 171/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3659e-04
# Epoch 172/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3737e-04
# Epoch 173/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4125e-04
# Epoch 174/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3683e-04
# Epoch 175/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3173e-04
# Epoch 176/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3277e-04
# Epoch 177/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2876e-04
# Epoch 178/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2724e-04
# Epoch 179/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2552e-04
# Epoch 180/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2708e-04
# Epoch 181/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2677e-04
# Epoch 182/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3828e-04
# Epoch 183/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3194e-04
# Epoch 184/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2487e-04
# Epoch 185/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3056e-04
# Epoch 186/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3156e-04
# Epoch 187/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2828e-04
# Epoch 188/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3581e-04
# Epoch 189/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3285e-04
# Epoch 190/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2744e-04
# Epoch 191/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3144e-04
# Epoch 192/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3241e-04
# Epoch 193/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4088e-04
# Epoch 194/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.3702e-04
# Epoch 195/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2714e-04
# Epoch 196/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2709e-04
# Epoch 197/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2393e-04
# Epoch 198/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2431e-04
# Epoch 199/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2849e-04
# Epoch 200/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.4114e-04
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn (RNN)                    multiple                  7400
# =================================================================
# Total params: 7,400
# Trainable params: 7,400
# Non-trainable params: 0
# _________________________________________________________________
# The training process takes: 439.63005661964417s

# %%
predict.shape
# Out:
# (499, 20)

# %%
#真实和预测结果
test_y_list=np.split(test_y,20,axis=1)
predict_list=np.split(predict,20,axis=1)
print(len(predict_list[0]))
for i in range(20):
    plt.figure(figsize=(10,5))
    plt.plot(test_y_list[i],label='real')
    plt.plot(predict_list[i],label='predict')
    plt.legend()
    plt.show()
# Out:
# 499

# %%
'''
test_y_list=np.split(test_y,10,axis=1)
predict_list=np.split(predict,10,axis=1)
for i in range(10):
    plt.figure(figsize=(10,5))
    plt.plot(test_y_list[i],label='real')
    plt.plot(predict_list[i],label='predict')
    plt.legend()
    plt.show()
'''
# Out:
# "\ntest_y_list=np.split(test_y,10,axis=1)\npredict_list=np.split(predict,10,axis=1)\nfor i in range(10):\n    plt.figure(figsize=(10,5))\n    plt.plot(test_y_list[i],label='real')\n    plt.plot(predict_list[i],label='predict')\n    plt.legend()\n    plt.show()\n"

# %%
print('rmse:{}'.format(np.sqrt(np.mean(np.square(predict-test_y)))))
# Out:
# rmse:0.025526314968570444

# %%
#选取增量最大的股票进行投递  数据为价格
def stragety():
    #init
    cap_str=100000
    cap_cg=[cap_str]
    for i in range(len(predict)-1):
        cur,ind=0,-1
        for j in range(input_size):
            if(predict[i+1][j]/predict[i][j]-1>cur):
                cur=predict[i+1][j]/predict[i][j]-1
                ind=j
        if cur>0:
            cap_str=cap_str*test_y[i+1][ind]/test_y[i][ind]
        cap_cg.append(cap_str)
    return cap_cg

def origin():
    cap_ori=100000
    cap_cg=[cap_ori]
    for i in range(len(predict)-1):
        cap_ori=cap_ori*test_y[i+1][0]/test_y[i][0]
        cap_cg.append(cap_ori)
    return cap_cg

# %%
#选取增量最大的股票进行投递  数据为增长率
def stragety_rate():
    #init
    cap_str=100000
    cap_cg=[cap_str]
    for i in range(len(predict)-1):
        cur,ind=0,-1
        for j in range(input_size):
            if(predict[i+1][j]>cur):
                cur=predict[i+1][j]
                ind=j
        if cur>0:
            cap_str=cap_str*(1+test_y[i+1][ind])
        cap_cg.append(cap_str)
    return cap_cg

def origin_rate():
    cap_ori=100000
    cap_cg=[cap_ori]
    for i in range(len(predict)-1):
        cap_ori=cap_ori*(1+test_y[i+1][0])
        cap_cg.append(cap_ori)
    return cap_cg

# %%
'''
#策略结果  数据为价格
cap_s=stragety()
cap_o=origin()
plt.plot(cap_s)
plt.plot(cap_o)
plt.show()
'''
# Out:
# '\n#策略结果  数据为价格\ncap_s=stragety()\ncap_o=origin()\nplt.plot(cap_s)\nplt.plot(cap_o)\nplt.show()\n'

# %%
#策略结果 数据为增长率
cap_s=stragety_rate()
cap_o=origin_rate()
plt.plot(cap_s)
plt.plot(cap_o)
plt.show()

# %%
def log():
