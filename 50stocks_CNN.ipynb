# %%
import pandas as pd
import time
import pandas_datareader.data as web
import datetime 
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
#数据开始和结束时间
start=datetime.datetime(2010,1,1)
end=datetime.datetime(2020,1,1)

# %%
#实验中提取的股票
#AAPL
#GOOGL
#INTC
#MSFT
#ORCL

# %%
web.get_data_yahoo('AAL',start,end).head(5)
# Out:
#             High   Low  Open  Close      Volume  Adj Close
# Date
# 2009-12-31  4.97  4.83  4.92   4.84   5268600.0   4.562870
# 2010-01-04  4.94  4.66  4.84   4.77   9837300.0   4.496876
# 2010-01-05  5.37  4.71  4.79   5.31  25212000.0   5.005957
# 2010-01-06  5.38  5.00  5.19   5.09  16597900.0   4.798555
# 2010-01-07  5.43  5.05  5.06   5.24  14033400.0   4.939965

# %%
#获得股票数据
stock_names = pd.read_csv('D:/DataMining/基于深度学习的金融时序预测/stock_list_name.csv', header=None)
tech = list(stock_names[0][1:50])
df=pd.DataFrame({'AAL':web.get_data_yahoo('AAL',start,end)['Adj Close']})
for i in tech:
    tmp=web.get_data_yahoo(i,start,end)['Adj Close']
    tmp=tmp.rename(i)
    df=pd.merge(df,tmp,how='left',left_index=True,right_index=True)

# %%
df.head()
#df.to_csv('D:/DataMining/基于深度学习的金融时序预测/stocks.csv')
# Out:
#                  AAL      AAPL       ADBE        ADI        ADP       ADSK  \
# Date
# 2009-12-31  4.562870  6.503574  36.779999  23.933790  28.693487  25.410000
# 2010-01-04  4.496876  6.604801  37.090000  24.001997  28.700174  25.670000
# 2010-01-05  5.005957  6.616219  37.700001  23.964100  28.546061  25.280001
# 2010-01-06  4.798555  6.510980  37.619999  23.918631  28.479050  25.340000
# 2010-01-07  4.939965  6.498945  36.889999  23.729166  28.465643  25.480000
#
#                  AKAM       ALXN       AMAT   AMD  ...       EXPE      FAST  \
# Date                                               ...
# 2009-12-31  25.340000  24.410000  11.226706  9.68  ...  33.893356  7.938684
# 2010-01-04  25.920000  24.125000  11.516642  9.70  ...  34.011906  8.013038
# 2010-01-05  26.690001  23.780001  11.428047  9.71  ...  34.156818  8.178905
# 2010-01-06  26.469999  23.840000  11.403889  9.57  ...  32.404835  8.718443
# 2010-01-07  26.480000  23.930000  11.283082  9.47  ...  32.233589  8.867153
#
#             FB       FFIV     FISV      FITB       FLIR  FOX  FOXA       GILD
# Date
# 2009-12-31 NaN  52.970001  12.1200  7.457723  28.743324  NaN   NaN  18.418251
# 2010-01-04 NaN  53.980000  12.3575  7.740736  28.664286  NaN   NaN  18.431015
# 2010-01-05 NaN  52.520000  12.4100  7.947258  28.734545  NaN   NaN  18.413992
# 2010-01-06 NaN  52.759998  12.3575  7.993153  28.804802  NaN   NaN  19.052479
# 2010-01-07 NaN  52.230000  12.3000  8.475036  28.839935  NaN   NaN  19.099298
#
# [5 rows x 50 columns]

# %%
#数据预处理
#df_pro=(df-df.mean())/df.std()
df_pro=(df.pct_change()).fillna(0)
#df_pro=(df-df.min())/(df.max()-df.min())

# %%
df_pro.head()
# Out:
#                  AAL      AAPL      ADBE       ADI       ADP      ADSK  \
# Date
# 2009-12-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2010-01-04 -0.014463  0.015565  0.008429  0.002850  0.000233  0.010232
# 2010-01-05  0.113208  0.001729  0.016446 -0.001579 -0.005370 -0.015193
# 2010-01-06 -0.041431 -0.015906 -0.002122 -0.001897 -0.002347  0.002373
# 2010-01-07  0.029469 -0.001848 -0.019405 -0.007921 -0.000471  0.005525
#
#                 AKAM      ALXN      AMAT       AMD  ...      EXPE      FAST  \
# Date                                                ...
# 2009-12-31  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2010-01-04  0.022889 -0.011676  0.025826  0.002066  ...  0.003498  0.009366
# 2010-01-05  0.029707 -0.014300 -0.007693  0.001031  ...  0.004261  0.020700
# 2010-01-06 -0.008243  0.002523 -0.002114 -0.014418  ... -0.051292  0.065967
# 2010-01-07  0.000378  0.003775 -0.010593 -0.010449  ... -0.005285  0.017057
#
#              FB      FFIV      FISV      FITB      FLIR  FOX  FOXA      GILD
# Date
# 2009-12-31  0.0  0.000000  0.000000  0.000000  0.000000  0.0   0.0  0.000000
# 2010-01-04  0.0  0.019067  0.019596  0.037949 -0.002750  0.0   0.0  0.000693
# 2010-01-05  0.0 -0.027047  0.004248  0.026680  0.002451  0.0   0.0 -0.000924
# 2010-01-06  0.0  0.004570 -0.004230  0.005775  0.002445  0.0   0.0  0.034674
# 2010-01-07  0.0 -0.010045 -0.004653  0.060287  0.001220  0.0   0.0  0.002457
#
# [5 rows x 50 columns]

# %%
#数据预览
plt.figure(figsize=(10,5))
for i in df_pro.columns:
    plt.plot(df_pro[i])
plt.show()

# %%
#参数
time_size=20
input_size=50
cnn_channels=200
cnn_kernel_len=2

# %%
#不重叠地切分 -- 250 *20 的数据量
#last=df_pro.shape[0]//time_size*time_size
#input_data=np.split(df_pro.values[:last],last/time_size,axis=0)
df_pro.shape[0] // time_size*time_size
# Out:
# 2500

# %%
#重叠切分
input_data=[]
output_data=[]
seq=df_pro.values
for i in range(len(seq)-time_size-1):
    input_data.append(seq[i:i+time_size])
    output_data.append(seq[i+time_size+1])
input_data=np.array(input_data)
output_data=np.array(output_data)

# %%
print(input_data.shape)
print(output_data.shape)
# Out:
# (2496, 20, 50)
# (2496, 50)

# %%
#实验模型
class ARNNCell(tf.keras.layers.Layer):
    def __init__(self, input_dim, output_dim):
        super(ARNNCell, self).__init__()
        self.input_dim=input_dim
        self.output_dim=output_dim
        self.w1=keras.layers.Dense(input_dim, activation='tanh')
        self.w2=keras.layers.Dense(input_dim, activation='tanh')
        self.w3=keras.layers.Dense(input_dim, activation='tanh')
        self.w4=keras.layers.Dense(output_dim, activation='linear')        
        self.state_size=(self.input_dim,self.input_dim)

    def call(self, inputs, states):
        pre_h=states[0]
        pre_h1=states[1]
        h=self.w2(inputs)+self.w3(pre_h)
        y=self.w1(inputs)*h
        h1=y+pre_h1
        return self.w4(h1), [h,h1]

def model_build_CNNATT():
    model=keras.Sequential([
        keras.layers.Reshape((time_size, input_size, 1), input_shape=(time_size, input_size)),
        keras.layers.Conv2D(cnn_channels, (cnn_kernel_len, input_size), activation='relu'),
        keras.layers.Reshape((19, cnn_channels)),
        keras.layers.RNN(ARNNCell(input_dim=200,output_dim=input_size))
    ])
    return model

# %%
#单层LSTM模型
def model_build_LSTM():
    model=keras.Sequential()
    model.add(keras.layers.LSTM(units=20,return_sequences=False))
    model.add(keras.layers.Activation('linear'))
    model.add(keras.layers.Dense(units=5))
    return model

# %%
##损失函数
def loss_(y_pred,y_true):
    return tf.reduce_mean(tf.square(y_pred-y_true))+tf.exp(-1*y_pred*y_true)
    #return tf.reduce_mean(tf.square(y_pred-y_true))+100*tf.exp(-(y_pred*y_true)/tf.abs(y_pred*y_true))
    #return tf.reduce_mean(tf.square(y_pred-y_true))+tf.exp(-10000*(y_pred*y_true))

# %%
#data to [train,test]
#数据切分成训练数据和测试数据
train_size=int(input_data.shape[0]*0.8)
train_x=input_data[:train_size]
test_x=input_data[train_size+1:]
train_y=output_data[:train_size]
test_y=output_data[train_size+1:]

# %%
#模型训练函数
def train_model(train_x,train_y,test_x,test_y):
    model=model_build_CNNATT()
    #model=model_build_LSTM()
    model_name='att'

    #model.compile(loss='mse',optimizer='adam')
    model.compile(loss='mse',optimizer='adam')
    history=model.fit(train_x,train_y,batch_size=4,epochs=200,verbose=1,shuffle=False)
    model.summary()
    
    loss = history.history['loss']
    predict=model.predict(test_x)
    return predict,loss,model_name

# %%
print(train_x.shape,test_x.shape,train_y.shape,test_y.shape)
# Out:
# (1996, 20, 50) (499, 20, 50) (1996, 50) (499, 50)

# %%
#训练模型
time_start = time.time()
predict,loss,model=train_model(train_x, train_y, test_x, test_y)
time_end = time.time()
print("The time used for training: " + str(time_end - time_start) + 's')
# Out:
# Train on 1996 samples
# Epoch 1/200
# 1996/1996 [==============================] - 6s 3ms/sample - loss: 3.3020e-04
# Epoch 2/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2976e-04
# Epoch 3/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2982e-04
# Epoch 4/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.3551e-04
# Epoch 5/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.3374e-04
# Epoch 6/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.3238e-04
# Epoch 7/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.3202e-04
# Epoch 8/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.3142e-04
# Epoch 9/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.3011e-04
# Epoch 10/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2939e-04
# Epoch 11/200
# 1996/1996 [==============================] - 5s 3ms/sample - loss: 3.2926e-04
# Epoch 12/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2922e-04
# Epoch 13/200
# 1996/1996 [==============================] - 5s 3ms/sample - loss: 3.3104e-04
# Epoch 14/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2957e-04
# Epoch 15/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2934e-04
# Epoch 16/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2923e-04
# Epoch 17/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.3308e-04
# Epoch 18/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2936e-04
# Epoch 19/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2922e-04
# Epoch 20/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 21/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 22/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 23/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2991e-04
# Epoch 24/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2922e-04
# Epoch 25/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2918e-04
# Epoch 26/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2920e-04
# Epoch 27/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2922e-04
# Epoch 28/200
# 1996/1996 [==============================] - 5s 3ms/sample - loss: 3.2927e-04
# Epoch 29/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2934e-04
# Epoch 30/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 31/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2921e-04
# Epoch 32/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2921e-04
# Epoch 33/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2920e-04
# Epoch 34/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2918e-04
# Epoch 35/200
# 1996/1996 [==============================] - 6s 3ms/sample - loss: 3.2919e-04
# Epoch 36/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2919e-04
# Epoch 37/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2918e-04
# Epoch 38/200
# 1996/1996 [==============================] - 5s 3ms/sample - loss: 3.2920e-04
# Epoch 39/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2917e-04
# Epoch 40/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2915e-04
# Epoch 41/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 42/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2913e-04
# Epoch 43/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2915e-04
# Epoch 44/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2917e-04
# Epoch 45/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2916e-04
# Epoch 46/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2915e-04
# Epoch 47/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 48/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2917e-04
# Epoch 49/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 50/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2921e-04
# Epoch 51/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 52/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 53/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2919e-04
# Epoch 54/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2917e-04
# Epoch 55/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2914e-04
# Epoch 56/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2920e-04
# Epoch 57/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 58/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2914e-04
# Epoch 59/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2918e-04
# Epoch 60/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2918e-04
# Epoch 61/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2916e-04
# Epoch 62/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2914e-04
# Epoch 63/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2916e-04
# Epoch 64/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 65/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 66/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2915e-04
# Epoch 67/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2916e-04
# Epoch 68/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2919e-04
# Epoch 69/200
# 1996/1996 [==============================] - 5s 3ms/sample - loss: 3.2916e-04
# Epoch 70/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2917e-04
# Epoch 71/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2917e-04
# Epoch 72/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2913e-04
# Epoch 73/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2913e-04
# Epoch 74/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2916e-04
# Epoch 75/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2921e-04
# Epoch 76/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2916e-04
# Epoch 77/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2918e-04
# Epoch 78/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2915e-04
# Epoch 79/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2919e-04
# Epoch 80/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2914e-04
# Epoch 81/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2918e-04
# Epoch 82/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2916e-04
# Epoch 83/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2914e-04
# Epoch 84/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2914e-04
# Epoch 85/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2914e-04
# Epoch 86/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2915e-04
# Epoch 87/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2918e-04
# Epoch 88/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2920e-04
# Epoch 89/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2919e-04
# Epoch 90/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2916e-04
# Epoch 91/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 92/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 93/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 94/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 95/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2915e-04
# Epoch 96/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 97/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 98/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2921e-04
# Epoch 99/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2915e-04
# Epoch 100/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2915e-04
# Epoch 101/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2919e-04
# Epoch 102/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 103/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 104/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 105/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 106/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2915e-04
# Epoch 107/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2921e-04
# Epoch 108/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 109/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 110/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 111/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 112/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 113/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2914e-04
# Epoch 114/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 115/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2921e-04
# Epoch 116/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2913e-04
# Epoch 117/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 118/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 119/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 120/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2916e-04
# Epoch 121/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2915e-04
# Epoch 122/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 123/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 124/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 125/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 126/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2914e-04
# Epoch 127/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 128/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 129/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 130/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 131/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2921e-04
# Epoch 132/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 133/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2915e-04
# Epoch 134/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 135/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 136/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 137/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 138/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 139/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 140/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 141/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 142/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 143/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 144/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 145/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 146/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 147/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 148/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 149/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 150/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 151/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 152/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 153/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2915e-04
# Epoch 154/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2917e-04
# Epoch 155/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2920e-04
# Epoch 156/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 157/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2921e-04
# Epoch 158/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2918e-04
# Epoch 159/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2918e-04
# Epoch 160/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2921e-04
# Epoch 161/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2916e-04
# Epoch 162/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2919e-04
# Epoch 163/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2917e-04
# Epoch 164/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2917e-04
# Epoch 165/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 166/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 167/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 168/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2920e-04
# Epoch 169/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 170/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2915e-04
# Epoch 171/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2917e-04
# Epoch 172/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 173/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 174/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 175/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2919e-04
# Epoch 176/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2915e-04
# Epoch 177/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2914e-04
# Epoch 178/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 179/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2916e-04
# Epoch 180/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 181/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 182/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 183/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2916e-04
# Epoch 184/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2914e-04
# Epoch 185/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2917e-04
# Epoch 186/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2916e-04
# Epoch 187/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04 0s -
# Epoch 188/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2915e-04
# Epoch 189/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 190/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 191/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2921e-04
# Epoch 192/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2916e-04
# Epoch 193/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2919e-04
# Epoch 194/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Epoch 195/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2917e-04
# Epoch 196/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.2919e-04
# Epoch 197/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2917e-04
# Epoch 198/200
# 1996/1996 [==============================] - 5s 2ms/sample - loss: 3.2918e-04
# Epoch 199/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2915e-04
# Epoch 200/200
# 1996/1996 [==============================] - 4s 2ms/sample - loss: 3.2918e-04
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 20, 50, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 19, 1, 200)        20200
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 19, 200)           0
# _________________________________________________________________
# rnn (RNN)                    (None, 50)                130650
# =================================================================
# Total params: 150,850
# Trainable params: 150,850
# Non-trainable params: 0
# _________________________________________________________________
# The time used for training: 828.95152759552s

# %%
predict.shape
# Out:
# (499, 50)

# %%
#真实和预测结果
test_y_list=np.split(test_y,50,axis=1)
predict_list=np.split(predict,50,axis=1)
for i in range(50):
    plt.figure(figsize=(10,5))
    plt.plot(test_y_list[i],label='real')
    plt.plot(predict_list[i],label='predict')
    plt.legend()
    plt.show()

# %%
'''
test_y_list=np.split(test_y,5,axis=1)
predict_list=np.split(predict,5,axis=1)
for i in range(5):
    plt.figure(figsize=(10,5))
    plt.plot(test_y_list[i],label='real')
    plt.plot(predict_list[i],label='predict')
    plt.legend()
    plt.show()
'''
# Out:
# "\ntest_y_list=np.split(test_y,5,axis=1)\npredict_list=np.split(predict,5,axis=1)\nfor i in range(5):\n    plt.figure(figsize=(10,5))\n    plt.plot(test_y_list[i],label='real')\n    plt.plot(predict_list[i],label='predict')\n    plt.legend()\n    plt.show()\n"

# %%
print('rmse:{}'.format(np.sqrt(np.mean(np.square(predict-test_y)))))
# Out:
# rmse:0.018893589208181176

# %%
#选取增量最大的股票进行投递  数据为价格
def stragety():
    #init
    cap_str=100000
    cap_cg=[cap_str]
    for i in range(len(predict)-1):
        cur,ind=0,-1
        for j in range(input_size):
            if(predict[i+1][j]/predict[i][j]-1>cur):
                cur=predict[i+1][j]/predict[i][j]-1
                ind=j
        if cur>0:
            cap_str=cap_str*test_y[i+1][ind]/test_y[i][ind]
        cap_cg.append(cap_str)
    return cap_cg

def origin():
    cap_ori=100000
    cap_cg=[cap_ori]
    for i in range(len(predict)-1):
        cap_ori=cap_ori*test_y[i+1][0]/test_y[i][0]
        cap_cg.append(cap_ori)
    return cap_cg

# %%
#选取增量最大的股票进行投递  数据为增长率
def stragety_rate():
    #init
    cap_str=100000
    cap_cg=[cap_str]
    for i in range(len(predict)-1):
        cur,ind=0,-1
        for j in range(input_size):
            if(predict[i+1][j]>cur):
                cur=predict[i+1][j]
                ind=j
        if cur>0:
            cap_str=cap_str*(1+test_y[i+1][ind])
        cap_cg.append(cap_str)
    return cap_cg

def origin_rate():
    cap_ori=100000
    cap_cg=[cap_ori]
    for i in range(len(predict)-1):
        cap_ori=cap_ori*(1+test_y[i+1][0])
        cap_cg.append(cap_ori)
    return cap_cg

# %%
'''
#策略结果  数据为价格
cap_s=stragety()
cap_o=origin()
plt.plot(cap_s)
plt.plot(cap_o)
plt.show()
'''
# Out:
# '\n#策略结果  数据为价格\ncap_s=stragety()\ncap_o=origin()\nplt.plot(cap_s)\nplt.plot(cap_o)\nplt.show()\n'

# %%
#策略结果 数据为增长率
cap_s=stragety_rate()
cap_o=origin_rate()
plt.plot(cap_s)
plt.plot(cap_o)
plt.show()

# %%
def log():
# Out:
#   File "<ipython-input-29-6153ca42db5c>", line 1
#     def log():
#               ^
# SyntaxError: unexpected EOF while parsing
