# %%
import pandas as pd
import pandas_datareader.data as web
import datetime
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
import time

# %%
#数据开始和结束时间
start=datetime.datetime(2010,1,1)
end=datetime.datetime(2020,1,1)

# %%
#实验中提取的股票
#AAPL
#GOOGL
#INTC
#MSFT
#ORCL

# %%
web.get_data_yahoo('AAL',start,end).head(5)
# Out:
#             High   Low  Open  Close      Volume  Adj Close
# Date
# 2009-12-31  4.97  4.83  4.92   4.84   5268600.0   4.562870
# 2010-01-04  4.94  4.66  4.84   4.77   9837300.0   4.496876
# 2010-01-05  5.37  4.71  4.79   5.31  25212000.0   5.005957
# 2010-01-06  5.38  5.00  5.19   5.09  16597900.0   4.798555
# 2010-01-07  5.43  5.05  5.06   5.24  14033400.0   4.939965

# %%
#获得股票数据
stock_names = pd.read_csv('D:/DataMining/基于深度学习的金融时序预测/stock_list_name.csv', header=None)
tech = list(stock_names[0][1:50])
df=pd.DataFrame({'AAL':web.get_data_yahoo('AAL',start,end)['Adj Close']})
for i in tech:
    tmp=web.get_data_yahoo(i,start,end)['Adj Close']
    tmp=tmp.rename(i)
    df=pd.merge(df,tmp,how='left',left_index=True,right_index=True)

# %%
df.head()
# Out:
#                  AAL      AAPL       ADBE        ADI        ADP       ADSK  \
# Date
# 2009-12-31  4.562870  6.503574  36.779999  23.933790  28.693487  25.410000
# 2010-01-04  4.496876  6.604801  37.090000  24.001997  28.700174  25.670000
# 2010-01-05  5.005957  6.616219  37.700001  23.964100  28.546061  25.280001
# 2010-01-06  4.798555  6.510980  37.619999  23.918631  28.479050  25.340000
# 2010-01-07  4.939965  6.498945  36.889999  23.729166  28.465643  25.480000
#
#                  AKAM       ALXN       AMAT   AMD  ...       EXPE      FAST  \
# Date                                               ...
# 2009-12-31  25.340000  24.410000  11.226706  9.68  ...  33.893356  7.938684
# 2010-01-04  25.920000  24.125000  11.516642  9.70  ...  34.011906  8.013038
# 2010-01-05  26.690001  23.780001  11.428047  9.71  ...  34.156818  8.178905
# 2010-01-06  26.469999  23.840000  11.403889  9.57  ...  32.404835  8.718443
# 2010-01-07  26.480000  23.930000  11.283082  9.47  ...  32.233589  8.867153
#
#             FB       FFIV     FISV      FITB       FLIR  FOX  FOXA       GILD
# Date
# 2009-12-31 NaN  52.970001  12.1200  7.457723  28.743324  NaN   NaN  18.418251
# 2010-01-04 NaN  53.980000  12.3575  7.740736  28.664286  NaN   NaN  18.431015
# 2010-01-05 NaN  52.520000  12.4100  7.947258  28.734545  NaN   NaN  18.413992
# 2010-01-06 NaN  52.759998  12.3575  7.993153  28.804802  NaN   NaN  19.052479
# 2010-01-07 NaN  52.230000  12.3000  8.475036  28.839935  NaN   NaN  19.099298
#
# [5 rows x 50 columns]

# %%
#数据预处理
#df_pro=(df-df.mean())/df.std()
df_pro=(df.pct_change()).fillna(0)
#df_pro=(df-df.min())/(df.max()-df.min())

# %%
df_pro.head()
# Out:
#                  AAL      AAPL      ADBE       ADI       ADP      ADSK  \
# Date
# 2009-12-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2010-01-04 -0.014463  0.015565  0.008429  0.002850  0.000233  0.010232
# 2010-01-05  0.113208  0.001729  0.016446 -0.001579 -0.005370 -0.015193
# 2010-01-06 -0.041431 -0.015906 -0.002122 -0.001897 -0.002347  0.002373
# 2010-01-07  0.029469 -0.001848 -0.019405 -0.007921 -0.000471  0.005525
#
#                 AKAM      ALXN      AMAT       AMD  ...      EXPE      FAST  \
# Date                                                ...
# 2009-12-31  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2010-01-04  0.022889 -0.011676  0.025826  0.002066  ...  0.003498  0.009366
# 2010-01-05  0.029707 -0.014300 -0.007693  0.001031  ...  0.004261  0.020700
# 2010-01-06 -0.008243  0.002523 -0.002114 -0.014418  ... -0.051292  0.065967
# 2010-01-07  0.000378  0.003775 -0.010593 -0.010449  ... -0.005285  0.017057
#
#              FB      FFIV      FISV      FITB      FLIR  FOX  FOXA      GILD
# Date
# 2009-12-31  0.0  0.000000  0.000000  0.000000  0.000000  0.0   0.0  0.000000
# 2010-01-04  0.0  0.019067  0.019596  0.037949 -0.002750  0.0   0.0  0.000693
# 2010-01-05  0.0 -0.027047  0.004248  0.026680  0.002451  0.0   0.0 -0.000924
# 2010-01-06  0.0  0.004570 -0.004230  0.005775  0.002445  0.0   0.0  0.034674
# 2010-01-07  0.0 -0.010045 -0.004653  0.060287  0.001220  0.0   0.0  0.002457
#
# [5 rows x 50 columns]

# %%
#数据预览
plt.figure(figsize=(10,5))
for i in df_pro.columns:
    plt.plot(df_pro[i])
plt.show()

# %%
#参数
time_size=20
input_size=50

# %%
#不重叠地切分 -- 250 *20 的数据量
#last=df_pro.shape[0]//time_size*time_size
#input_data=np.split(df_pro.values[:last],last/time_size,axis=0)

# %%
#重叠切分
input_data=[]
output_data=[]
seq=df_pro.values
for i in range(len(seq)-time_size-1):
    input_data.append(seq[i:i+time_size])
    output_data.append(seq[i+time_size+1])
input_data=np.array(input_data)
output_data=np.array(output_data)

# %%
print(input_data.shape)
print(output_data.shape)
# Out:
# (2496, 20, 50)
# (2496, 50)

# %%
#实验模型
class ARNNCell(tf.keras.layers.Layer):
    def __init__(self, input_dim, output_dim):
        super(ARNNCell, self).__init__()
        self.input_dim=input_dim
        self.output_dim=output_dim
        self.w1=keras.layers.Dense(input_dim, activation='tanh')
        self.w2=keras.layers.Dense(input_dim, activation='tanh')
        self.w3=keras.layers.Dense(input_dim, activation='tanh')
        self.w4=keras.layers.Dense(output_dim, activation='linear')        
        self.state_size=(self.input_dim,self.input_dim)

    def call(self, inputs, states):
        pre_h=states[0]
        pre_h1=states[1]
        h=self.w2(inputs)+self.w3(pre_h)
        y=self.w1(inputs)*h
        h1=y+pre_h1
        return self.w4(h1), [h,h1]

def model_build_ATT():
    model=keras.Sequential(keras.layers.RNN(ARNNCell(input_dim=120,output_dim=50)))
    return model

# %%
#单层LSTM模型
def model_build_LSTM():
    model=keras.Sequential()
    model.add(keras.layers.LSTM(units=20,return_sequences=False))
    model.add(keras.layers.Activation('linear'))
    model.add(keras.layers.Dense(units=5))
    return model

# %%
##损失函数
def loss_(y_pred,y_true):
    return tf.reduce_mean(tf.square(y_pred-y_true))+tf.exp(-1*y_pred*y_true)
    #return tf.reduce_mean(tf.square(y_pred-y_true))+100*tf.exp(-(y_pred*y_true)/tf.abs(y_pred*y_true))
    #return tf.reduce_mean(tf.square(y_pred-y_true))+tf.exp(-10000*(y_pred*y_true))

# %%
#data to [train,test]
#数据切分成训练数据和测试数据
train_size=int(input_data.shape[0]*0.8)
train_x=input_data[:train_size]
test_x=input_data[train_size+1:]
train_y=output_data[:train_size]
test_y=output_data[train_size+1:]

# %%
#模型训练函数
def train_model(train_x,train_y,test_x,test_y):
    model=model_build_ATT()
    #model=model_build_LSTM()
    model_name='att'

    #model.compile(loss='mse',optimizer='adam')
    model.compile(loss='mse',optimizer='adam')
    history=model.fit(train_x,train_y,batch_size=4,epochs=200,verbose=1,shuffle=False)
    model.summary()
    
    loss = history.history['loss']
    predict=model.predict(test_x)
    return predict,loss,model_name

# %%
print(train_x.shape,test_x.shape,train_y.shape,test_y.shape)
# Out:
# (1996, 20, 50) (499, 20, 50) (1996, 50) (499, 50)

# %%
#训练模型
time_start = time.time()
predict,loss,model=train_model(train_x, train_y, test_x, test_y)
time_end = time.time()
print("The training process takes: " + str(time_end - time_start) + 's')
# Out:
# Train on 1996 samples
# Epoch 1/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 3.3645e-04
# Epoch 2/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.2916e-04
# Epoch 3/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.2899e-04
# Epoch 4/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2336e-04
# Epoch 5/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.2032e-04
# Epoch 6/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1910e-04
# Epoch 7/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.1851e-04
# Epoch 8/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.1740e-04
# Epoch 9/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1495e-04
# Epoch 10/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1592e-04
# Epoch 11/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1600e-04
# Epoch 12/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1395e-04
# Epoch 13/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1257e-04
# Epoch 14/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1223e-04
# Epoch 15/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1201e-04
# Epoch 16/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1203e-04
# Epoch 17/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0816e-04
# Epoch 18/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1159e-04
# Epoch 19/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0607e-04
# Epoch 20/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1316e-04
# Epoch 21/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1001e-04
# Epoch 22/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.1031e-04
# Epoch 23/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0742e-04
# Epoch 24/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.0798e-04
# Epoch 25/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.0996e-04
# Epoch 26/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.0737e-04
# Epoch 27/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0208e-04
# Epoch 28/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9957e-04
# Epoch 29/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0111e-04
# Epoch 30/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0180e-04
# Epoch 31/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0193e-04
# Epoch 32/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0220e-04
# Epoch 33/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.0467e-04
# Epoch 34/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.0612e-04
# Epoch 35/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.0108e-04
# Epoch 36/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.0356e-04
# Epoch 37/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 3.0489e-04
# Epoch 38/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9908e-04
# Epoch 39/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0221e-04
# Epoch 40/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0103e-04
# Epoch 41/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0462e-04
# Epoch 42/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0137e-04
# Epoch 43/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 3.0061e-04
# Epoch 44/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9583e-04
# Epoch 45/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9565e-04
# Epoch 46/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9521e-04
# Epoch 47/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9836e-04
# Epoch 48/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9915e-04
# Epoch 49/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9473e-04
# Epoch 50/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9244e-04
# Epoch 51/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9239e-04
# Epoch 52/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9365e-04
# Epoch 53/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9242e-04
# Epoch 54/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9111e-04
# Epoch 55/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9665e-04
# Epoch 56/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9518e-04
# Epoch 57/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9459e-04
# Epoch 58/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9709e-04
# Epoch 59/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9245e-04
# Epoch 60/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9209e-04
# Epoch 61/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9281e-04
# Epoch 62/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.9532e-04
# Epoch 63/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.8592e-04
# Epoch 64/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.8000e-04
# Epoch 65/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.8200e-04
# Epoch 66/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.8523e-04
# Epoch 67/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.8749e-04
# Epoch 68/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.8559e-04
# Epoch 69/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9083e-04
# Epoch 70/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9152e-04
# Epoch 71/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.8491e-04
# Epoch 72/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.8837e-04
# Epoch 73/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.8533e-04
# Epoch 74/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7800e-04
# Epoch 75/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7652e-04
# Epoch 76/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.8333e-04
# Epoch 77/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7743e-04
# Epoch 78/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7620e-04
# Epoch 79/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7322e-04
# Epoch 80/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7462e-04
# Epoch 81/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7891e-04
# Epoch 82/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.8492e-04
# Epoch 83/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.8276e-04
# Epoch 84/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7915e-04
# Epoch 85/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.8509e-04
# Epoch 86/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7081e-04
# Epoch 87/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7984e-04
# Epoch 88/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.9498e-04
# Epoch 89/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.8027e-04
# Epoch 90/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7106e-04
# Epoch 91/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7632e-04
# Epoch 92/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7869e-04
# Epoch 93/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6944e-04
# Epoch 94/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6580e-04
# Epoch 95/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6791e-04
# Epoch 96/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7221e-04
# Epoch 97/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7622e-04
# Epoch 98/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7898e-04
# Epoch 99/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7242e-04
# Epoch 100/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6789e-04
# Epoch 101/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6646e-04
# Epoch 102/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7010e-04
# Epoch 103/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7823e-04
# Epoch 104/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7315e-04
# Epoch 105/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6395e-04
# Epoch 106/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7222e-04
# Epoch 107/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7064e-04
# Epoch 108/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6308e-04
# Epoch 109/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6459e-04
# Epoch 110/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6629e-04
# Epoch 111/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6747e-04
# Epoch 112/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7199e-04
# Epoch 113/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7471e-04
# Epoch 114/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6754e-04
# Epoch 115/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6522e-04
# Epoch 116/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 2.6675e-04
# Epoch 117/200
# 1996/1996 [==============================] - 3s 2ms/sample - loss: 2.7084e-04
# Epoch 118/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6765e-04
# Epoch 119/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6282e-04
# Epoch 120/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6578e-04
# Epoch 121/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6316e-04
# Epoch 122/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6620e-04
# Epoch 123/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7291e-04
# Epoch 124/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6619e-04
# Epoch 125/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7358e-04
# Epoch 126/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6833e-04
# Epoch 127/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6197e-04
# Epoch 128/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7002e-04
# Epoch 129/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7173e-04
# Epoch 130/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6437e-04
# Epoch 131/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6965e-04
# Epoch 132/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6835e-04
# Epoch 133/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6541e-04
# Epoch 134/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.5752e-04
# Epoch 135/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5934e-04
# Epoch 136/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6894e-04
# Epoch 137/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.7251e-04
# Epoch 138/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5749e-04
# Epoch 139/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6181e-04
# Epoch 140/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.7199e-04
# Epoch 141/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6904e-04
# Epoch 142/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5820e-04
# Epoch 143/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6241e-04
# Epoch 144/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6165e-04
# Epoch 145/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6262e-04
# Epoch 146/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6249e-04
# Epoch 147/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6157e-04
# Epoch 148/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6208e-04
# Epoch 149/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6106e-04
# Epoch 150/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5730e-04
# Epoch 151/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5888e-04
# Epoch 152/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6019e-04
# Epoch 153/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6582e-04
# Epoch 154/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6990e-04
# Epoch 155/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.5791e-04
# Epoch 156/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5625e-04
# Epoch 157/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5875e-04
# Epoch 158/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6333e-04
# Epoch 159/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5659e-04
# Epoch 160/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6133e-04
# Epoch 161/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6107e-04
# Epoch 162/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5450e-04
# Epoch 163/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5636e-04
# Epoch 164/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5989e-04
# Epoch 165/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6345e-04
# Epoch 166/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6559e-04
# Epoch 167/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5743e-04
# Epoch 168/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5567e-04
# Epoch 169/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5725e-04
# Epoch 170/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5596e-04
# Epoch 171/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.5685e-04
# Epoch 172/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6225e-04
# Epoch 173/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.6168e-04
# Epoch 174/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.5433e-04
# Epoch 175/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5798e-04
# Epoch 176/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6632e-04
# Epoch 177/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5730e-04
# Epoch 178/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5632e-04
# Epoch 179/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5592e-04
# Epoch 180/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5141e-04
# Epoch 181/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5687e-04
# Epoch 182/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5734e-04
# Epoch 183/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.4704e-04
# Epoch 184/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5058e-04
# Epoch 185/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.4827e-04
# Epoch 186/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.4814e-04
# Epoch 187/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.5602e-04
# Epoch 188/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.5758e-04
# Epoch 189/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5215e-04
# Epoch 190/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.4816e-04
# Epoch 191/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.5394e-04
# Epoch 192/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6378e-04
# Epoch 193/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5612e-04
# Epoch 194/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.4925e-04
# Epoch 195/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5000e-04
# Epoch 196/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.5154e-04
# Epoch 197/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.4671e-04
# Epoch 198/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.4821e-04
# Epoch 199/200
# 1996/1996 [==============================] - 3s 1ms/sample - loss: 2.6288e-04
# Epoch 200/200
# 1996/1996 [==============================] - 2s 1ms/sample - loss: 2.5568e-04
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rnn (RNN)                    multiple                  32810
# =================================================================
# Total params: 32,810
# Trainable params: 32,810
# Non-trainable params: 0
# _________________________________________________________________
# The training process takes: 517.0071053504944s

# %%
predict.shape
# Out:
# (499, 50)

# %%
#真实和预测结果
test_y_list=np.split(test_y,50,axis=1)
predict_list=np.split(predict,50,axis=1)
print(len(predict_list[0]))
for i in range(50):
    plt.figure(figsize=(10,5))
    plt.plot(test_y_list[i],label='real')
    plt.plot(predict_list[i],label='predict')
    plt.legend()
    plt.show()
# Out:
# 499

# %%
'''
test_y_list=np.split(test_y,10,axis=1)
predict_list=np.split(predict,10,axis=1)
for i in range(10):
    plt.figure(figsize=(10,5))
    plt.plot(test_y_list[i],label='real')
    plt.plot(predict_list[i],label='predict')
    plt.legend()
    plt.show()
'''
# Out:
# "\ntest_y_list=np.split(test_y,10,axis=1)\npredict_list=np.split(predict,10,axis=1)\nfor i in range(10):\n    plt.figure(figsize=(10,5))\n    plt.plot(test_y_list[i],label='real')\n    plt.plot(predict_list[i],label='predict')\n    plt.legend()\n    plt.show()\n"

# %%
print('rmse:{}'.format(np.sqrt(np.mean(np.square(predict-test_y)))))
# Out:
# rmse:0.023658457747716747

# %%
#选取增量最大的股票进行投递  数据为价格
def stragety():
    #init
    cap_str=100000
    cap_cg=[cap_str]
    for i in range(len(predict)-1):
        cur,ind=0,-1
        for j in range(input_size):
            if(predict[i+1][j]/predict[i][j]-1>cur):
                cur=predict[i+1][j]/predict[i][j]-1
                ind=j
        if cur>0:
            cap_str=cap_str*test_y[i+1][ind]/test_y[i][ind]
        cap_cg.append(cap_str)
    return cap_cg

def origin():
    cap_ori=100000
    cap_cg=[cap_ori]
    for i in range(len(predict)-1):
        cap_ori=cap_ori*test_y[i+1][0]/test_y[i][0]
        cap_cg.append(cap_ori)
    return cap_cg

# %%
#选取增量最大的股票进行投递  数据为增长率
def stragety_rate():
    #init
    cap_str=100000
    cap_cg=[cap_str]
    for i in range(len(predict)-1):
        cur,ind=0,-1
        for j in range(input_size):
            if(predict[i+1][j]>cur):
                cur=predict[i+1][j]
                ind=j
        if cur>0:
            cap_str=cap_str*(1+test_y[i+1][ind])
        cap_cg.append(cap_str)
    return cap_cg

def origin_rate():
    cap_ori=100000
    cap_cg=[cap_ori]
    for i in range(len(predict)-1):
        cap_ori=cap_ori*(1+test_y[i+1][0])
        cap_cg.append(cap_ori)
    return cap_cg

# %%
'''
#策略结果  数据为价格
cap_s=stragety()
cap_o=origin()
plt.plot(cap_s)
plt.plot(cap_o)
plt.show()
'''
# Out:
# '\n#策略结果  数据为价格\ncap_s=stragety()\ncap_o=origin()\nplt.plot(cap_s)\nplt.plot(cap_o)\nplt.show()\n'

# %%
#策略结果 数据为增长率
cap_s=stragety_rate()
cap_o=origin_rate()
plt.plot(cap_s)
plt.plot(cap_o)
plt.show()

# %%
def log():
